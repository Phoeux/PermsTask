# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

from api.models import Plotter

Plotter.objects.all()

plotter_stats = Plotter.objects.all()
df = pd.DataFrame(plotter_stats.values('id', 'title', 'whole_amount'))
df
# Out:
#     id           title  whole_amount
# 0    1       ewfwerwer            23
# 1    2          werwer            11
# 2    3          23423r            43
# 3    4        hey54e6y             4
# 4    5          dealer            66
# 5    6         dealer2             0
# 6    7        usertest            72
# 7    8     тест фор 32            80
# 8    9  derwewr234r234           115
# 9   10  цукцукцук22233             0
# 10  11       123124234             0

# %%
sb.scatterplot(x='title', y='whole_amount', data=df)
plt.savefig("/home/gleb/Downloads/Stats.pdf", dpi=500)

# %%
sb.displot(df['whole_amount'])

# %%
gr = sb.catplot(x='title', y='whole_amount', data=df, kind='bar', aspect=3)
gr.savefig("Stats.pdf", dpi=500)
